# %%
# Data Analysis Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import os
import pickle
import itertools

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# util funcs to create bioguide_id - party - congress
import match_bioguide_party_utils

# %% [markdown]
# # Load in ProPub Data

# %%
fp = "data/propub_data.pickle"

# %%
if os.path.exists(fp):
    with open(fp,'rb') as f:
        propub_data = pickle.load(f)
else:
    key = ''
    propub_data = match_bioguide_party_utils.load_propublica_congress_api(key)
    
    with open(fp,'wb') as f:
        pickle.dump(propub_data,f)

# %% [markdown]
# # Load in House Exp. Data

# %%
# generated from R cleaning files
df_house = pd.read_csv("data/data.csv")

# %%
# force lower columns if not already
df_house.columns = [x.lower() for x in df_house.columns]

# %%
# Currently staffers fall under PERSONAL COMPENSATION
df_pc = df_house[df_house["category"] == "personnel compensation"]

# %% [markdown]
# # Generate Matching Between ID - Party - Congress

# %%
df_bioid_party_lookup,df_bioid_party = match_bioguide_party_utils.generate_bioid_party_lookup(df_pc,propub_data)

# %%
# cast as type int so it's orderd chronologically
df_bioid_party["congress"] = df_bioid_party["congress"].astype(int)

df_bioid_party["year_clean"] = df_bioid_party["year_clean"].astype(int)

# %%
df_sliced = df_bioid_party[["payee","category","purpose","office_cc","amount","party","congress","quarter_clean","year_clean"]]

# %%
df_unique_id = df_sliced.groupby(["payee","congress","party","purpose","office_cc","quarter_clean","year_clean"])["amount"].sum().reset_index()

# %% [markdown]
# # Tracking Staffers Over Time

# %% [markdown]
# We want to see which staffers appear more than once in the house exp. data

# %%
df_more_than_one = df_unique_id[df_unique_id['payee'].duplicated(keep=False)]

# %%
df_multi = df_more_than_one.groupby("payee").agg({"congress":lambda x: x.nunique(),"party":lambda x: x.nunique()})

# %% [markdown]
# Here we can look at which staffers have also served in multiple congress sessions

# %%
df_multi.sort_values(["congress","party"],ascending = False).head(10)
# Out:
#                       congress  party
# payee
# anfinson susan               5      2
# anfinson t e                 5      2
# awan abid a                  5      2
# baugh r p                    5      2
# blankenship april l          5      2
# donches michelle m           5      2
# elliott jennifer l           5      2
# fratter bonnie b             5      2
# fredericks autumn            5      2
# henry bryant heather         5      2

# %% [markdown]
# Interesting enough, it seems some staffers have even jumped across parties!

# %% [markdown]
# # Looking at Top Repeating

# %% [markdown]
# We'll look more closely at the people who've served the longest and for different parties.

# %%
df_five = df_multi[df_multi["congress"] > 4]

# %%
df_five_house = df_sliced[df_sliced["payee"].isin(df_five.index)]

# %%
"Number of unique individiuals who have served in more than four sessions {}".format(len(df_five_house["payee"].unique()))
# Out:
# 'Number of unique individiuals who have served in more than four sessions 22'

# %%
df_five_house.sort_values(["payee","quarter_clean","year_clean"])
# Out:
#                 payee                category  \
# 1244   anfinson susan  personnel compensation
# 2293   anfinson susan  personnel compensation
# 2414   anfinson susan  personnel compensation
# 3253   anfinson susan  personnel compensation
# 5532   anfinson susan  personnel compensation
# 5576   anfinson susan  personnel compensation
# 5986   anfinson susan  personnel compensation
# 8712   anfinson susan  personnel compensation
# 8713   anfinson susan  personnel compensation
# 10369  anfinson susan  personnel compensation
# 10370  anfinson susan  personnel compensation
# 13194  anfinson susan  personnel compensation
# 13577  anfinson susan  personnel compensation
# 14327  anfinson susan  personnel compensation
# 16506  anfinson susan  personnel compensation
# 17819  anfinson susan  personnel compensation
# 309    anfinson susan  personnel compensation
# 71766                   part time employee   hon christopher h smith  5250.00
# 71885                      shared employee         hon steve stivers  5241.67
# 30153                      shared employee      hon blake farenthold  3333.34
# 31307                      shared employee         hon joseph j heck  5000.01
# 32434              financial administrator            hon tom latham  1666.67
# 33211                      shared employee  hon howard p buck mckeon  6125.01
# 33470                    finance assistant           hon jeff miller  6875.01
# 35702                   part time employee   hon christopher h smith  5250.00
# 35836                      shared employee         hon steve stivers  5000.01
# 76477                      shared employee         hon joseph j heck  5000.01
# 77569              financial administrator            hon tom latham  5000.01
# 78300                      shared employee  hon howard p buck mckeon  6125.01
# 78535                    finance assistant           hon jeff miller  6875.01
# 80676                   part time employee   hon christopher h smith  5250.00
# 80811                      shared employee         hon steve stivers  5000.01
# 40777                      shared employee         hon joseph j heck  5000.01
# 41983              financial administrator            hon tom latham  5000.01
# 42799                      shared employee  hon howard p buck mckeon  6125.01
# 43059                    finance assistant           hon jeff miller  6875.01
# 45395                   part time employee   hon christopher h smith  5250.00
# 45516                      shared employee         hon steve stivers  5483.33
# 85629                      shared employee         hon joseph j heck  5000.01
# 86842              financial administrator            hon tom latham  5000.01
# 87637                      shared employee  hon howard p buck mckeon  6125.01
# 87920                    finance assistant           hon jeff miller  6875.01
# 90209                   part time employee   hon christopher h smith  5250.00
# 90341                      shared employee         hon steve stivers  5000.01
#
#       party  congress quarter_clean  year_clean
# 1244      R       115            q1        2010
# 2293      R       113            q1        2010
# 2414      R       113            q1        2010
# 3253      R       115            q1        2010
# 5532      R       114            q1        2010
# 5576      R       115            q1        2010
# 5986      R       113            q1        2010
# 8712      D       111            q1        2010
# 8713      D       111            q1        2010
# 10369     D       111            q1        2010
# 10370     D       111            q1        2010
# 13194     R       114            q1        2010
# 13577     R       111            q1        2010
# 14327     R       115            q1        2010
# 16506     D       112            q1        2010
# 17819     R       114            q1        2010
# 309       R       112            q1        2011
# 310       R       112            q1        2011
# 1220      R       115            q1        2011
# 1866      R       113            q1        2011
# 1867      R       113            q1        2011
# 2276      R       113            q1        2011
# 2391      R       113            q1        2011
# 3064      D       115            q1        2011
# 3233      R       115            q1        2011
# 3329      R       115            q1        2011
# 3685      R       115            q1        2011
# 4287      R       115            q1        2011
# 5507      R       114            q1        2011
# 5552      R       115            q1        2011
# ...     ...       ...           ...         ...
# 68615     R       113            q2        2012
# 69360     R       113            q2        2012
# 69607     R       114            q2        2012
# 71766     R       115            q2        2012
# 71885     R       115            q2        2012
# 30153     R       115            q3        2011
# 31307     R       114            q3        2011
# 32434     R       113            q3        2011
# 33211     R       113            q3        2011
# 33470     R       114            q3        2011
# 35702     R       115            q3        2011
# 35836     R       115            q3        2011
# 76477     R       114            q3        2012
# 77569     R       113            q3        2012
# 78300     R       113            q3        2012
# 78535     R       114            q3        2012
# 80676     R       115            q3        2012
# 80811     R       115            q3        2012
# 40777     R       114            q4        2011
# 41983     R       113            q4        2011
# 42799     R       113            q4        2011
# 43059     R       114            q4        2011
# 45395     R       115            q4        2011
# 45516     R       115            q4        2011
# 85629     R       114            q4        2012
# 86842     R       113            q4        2012
# 87637     R       113            q4        2012
# 87920     R       114            q4        2012
# 90209     R       115            q4        2012
# 90341     R       115            q4        2012
#
# [4883 rows x 9 columns]
